# %% [markdown]
# Â«alphaÂ»-Pinene, Camphene, Benzaldehyde, Â«betaÂ»-Pinene, Â«betaÂ»-Myrcene, Octanal, 1-hexanol,
# Limonene, Eucalyptol, 1-octanol, Nonanal, (-)-Myrtenol, Lilac aldehyde B, Lilac aldehyde C, Lilac aldehyde D,
# Lilac alcohol B
#
# Where is 2-ethyl-1-hexanol?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data= pd.read_excel('OutputScriptMarie_KovatsMatchOnly70.xlsx.xlsx', sheetname ='to use for NDMS')

# %%
#NORMALIZATION DATA BY SUM
for i in range(0, data.shape[0]):
    data.iloc[i, 2:] = data.iloc[i,2:] / sum(data.iloc[i,2:])

chemicals = ["Â«alphaÂ»-Pinene", "Camphene", "Benzaldehyde", "Â«betaÂ»-Pinene", "Â«betaÂ»-Myrcene", "Octanal", "1-hexanol",
"Limonene", "Eucalyptol", "1-octanol", "Nonanal", "(-)-Myrtenol", "Lilac aldehyde B", "Lilac aldehyde C","Lilac aldehyde D",
"Lilac alcohol B"]

data2 =  np.zeros(shape = (data.shape[0], len(chemicals)))

for i in range(len(chemicals)):
    for j in range(data.shape[1]):
        if list(data)[j] == chemicals[i]:
            data2[:,i] =  data.iloc[:,j]

#for i in range(len(chemicals)):
    #= data.iloc[data.iloc[1,:].str.contains(chemicals[i])]
data2 = pd.DataFrame(data2)

# %%
#SUBSET DATA BY SPECIES FOR PLOT MEAN ABUNDANCE CHEMICAL
data_Obt = data2.iloc[0:39, :]
data_Dil = data2.iloc[53:70, :]
data_Stri = data2.iloc[88:105, :]
data_Cil = data2.iloc[105:111, :] 
data_Hur = data2.iloc[78:88, :]

# %%
print ('The sample size of each group is', data_Obt.shape,  data_Dil.shape,  data_Stri.shape,  data_Cil.shape,  data_Hur.shape)
# Out:
# The sample size of each group is (39, 16) (17, 16) (17, 16) (6, 16) (10, 16)

# %%
from matplotlib.collections import LineCollection

from sklearn import manifold
from sklearn.metrics import euclidean_distances
from sklearn.decomposition import PCA
data2
# Out:
#            0         1         2         3         4         5    6   \
# 0    0.000000  0.049097  0.025931  0.000000  0.000000  0.000000  0.0
# 1    0.000000  0.145782  0.040355  0.000000  0.025867  0.000000  0.0
# 2    0.000000  0.121340  0.043574  0.000000  0.000000  0.000000  0.0
# 3    0.000000  0.097283  0.036913  0.152008  0.000000  0.000000  0.0
# 4    0.000000  0.066209  0.000000  0.097466  0.000000  0.000000  0.0
# 5    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 6    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
# 7    0.000000  0.037039  0.049935  0.000000  0.047204  0.000000  0.0
# 8    0.651792  0.000000  0.042233  0.000000  0.043557  0.000000  0.0
# 9    0.000000  0.245913  0.068102  0.000000  0.148461  0.000000  0.0
# 10   0.000000  0.180235  0.053804  0.295823  0.000000  0.000000  0.0
# 11   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.0
#
# 97   0.000000  0.000000  0.0  0.720381  0.000000  0.000000  0.0  0.000000
# 98   0.025440  0.000000  0.0  0.434010  0.000000  0.000000  0.0  0.000000
# 99   0.000000  0.000000  0.0  1.000000  0.000000  0.000000  0.0  0.000000
# 100  0.000000  0.000000  0.0  0.553945  0.000000  0.000000  0.0  0.000000
# 101  0.051497  0.000000  0.0  0.000000  0.000000  0.593967  0.0  0.000000
# 102  0.023359  0.000000  0.0  0.000000  0.000000  0.786725  0.0  0.065555
# 103  0.043974  0.000000  0.0  0.000000  0.000000  0.874655  0.0  0.000000
# 104  0.009357  0.000000  0.0  0.000000  0.000000  0.856328  0.0  0.080300
# 105  0.063219  0.000000  0.0  0.092647  0.000000  0.000000  0.0  0.000000
# 106  0.237267  0.000000  0.0  0.462403  0.000000  0.000000  0.0  0.000000
# 107  0.093414  0.133619  0.0  0.115637  0.000000  0.000000  0.0  0.000000
# 108  0.046188  0.000000  0.0  0.091411  0.000000  0.000000  0.0  0.000000
# 109  0.195296  0.000000  0.0  0.530397  0.000000  0.000000  0.0  0.000000
# 110  0.140297  0.000000  0.0  0.399755  0.000000  0.000000  0.0  0.000000
# 111  0.021635  0.000000  0.0  0.023875  0.000000  0.000000  0.0  0.000000
# 112  0.012779  0.000000  0.0  0.048707  0.000000  0.000000  0.0  0.000000
# 113  0.025877  0.000000  0.0  0.049760  0.000000  0.000000  0.0  0.000000
# 114  0.020728  0.000000  0.0  0.127373  0.000000  0.596637  0.0  0.000000
# 115  0.000000  0.000000  0.0  0.004386  0.000000  0.588936  0.0  0.000000
# 116  0.001373  0.000000  0.0  0.008222  0.000000  0.736484  0.0  0.047568
# 117  0.004943  0.000000  0.0  0.007110  0.000000  0.000000  0.0  0.000000
# 118  0.000000  0.000000  0.0  0.015967  0.000000  0.000000  0.0  0.000000
# 119  0.006096  0.000000  0.0  0.029323  0.000000  0.000000  0.0  0.000000
#
#            15
# 0    0.000000
# 1    0.000000
# 2    0.000000
# 3    0.000000
# 4    0.000000
# 5    0.000000
# 6    0.000000
# 7    0.000000
# 8    0.000000
# 9    0.000000
# 10   0.000000
# 11   0.000000
# 12   0.000000
# 13   0.000000
# 14   0.000000
# 15   0.000000
# 16   0.000000
# 17   0.035831
# 18   0.000000
# 19   0.000000
# 20   0.000000
# 21   0.000000
# 22   0.000000
# 23   0.000000
# 24   0.000000
# 25   0.000000
# 26   0.000000
# 27   0.000000
# 28   0.000000
# 29   0.000000
# ..        ...
# 90   0.000000
# 91   0.000000
# 92   0.000000
# 93   0.000000
# 94   0.000000
# 95   0.000000
# 96   0.000000
# 97   0.000000
# 98   0.046568
# 99   0.000000
# 100  0.059800
# 101  0.000000
# 102  0.000000
# 103  0.000000
# 104  0.000000
# 105  0.000000
# 106  0.000000
# 107  0.000000
# 108  0.000000
# 109  0.000000
# 110  0.000000
# 111  0.000000
# 112  0.000000
# 113  0.000000
# 114  0.000000
# 115  0.000000
# 116  0.000000
# 117  0.000000
# 118  0.000000
# 119  0.000000
#
# [120 rows x 16 columns]

# %%
similarities = euclidean_distances(data2)
#similarities = pd.DataFrame(similarities)

# %%
stress= np.zeros(10)
for i in range(10):
    mds = manifold.MDS(n_components=i+1, max_iter=3000, eps=1e-9, 
                   dissimilarity="precomputed", n_jobs=1)
    pos = mds.fit(similarities).embedding_
    nmds = manifold.MDS(n_components=i+1, metric=False, max_iter=3000, eps=1e-12,
                    dissimilarity="precomputed", n_jobs=1)
    npos = nmds.fit_transform(similarities, init=pos)
    stress[i] = nmds.stress_
# Out:
# /Users/ryokubo/anaconda/lib/python3.5/site-packages/sklearn/manifold/mds.py:238: UserWarning: Explicit initial positions passed: performing only one init of the MDS instead of 4
#   % n_init)

# %%
stress
plt.plot(range(10), stress, 'o')
#plt.ylim(-0.5, 5)
#plt.xlim(-0.5, 4.5)
#plt.xaxis([1, 2, 3, 4, 5])
stress
# Out:
# array([  3.41737033e+02,   4.43050651e+01,   1.21608118e+01,
#          4.63724788e+00,   2.00882016e+00,   9.92168145e-01,
#          4.63957872e-01,   1.88172051e-01,   4.87963333e-02,
#          1.09104715e-02])

# %%
mds = manifold.MDS(n_components=6, max_iter=3000, eps=1e-9, 
                   dissimilarity="precomputed", n_jobs=1)
pos = mds.fit(similarities).embedding_
nmds = manifold.MDS(n_components=6, metric=False, max_iter=3000, eps=1e-12,
                    dissimilarity="precomputed", n_jobs=1)
npos = nmds.fit_transform(similarities, init=pos)
# Out:
# /Users/ryokubo/anaconda/lib/python3.5/site-packages/sklearn/manifold/mds.py:238: UserWarning: Explicit initial positions passed: performing only one init of the MDS instead of 4
#   % n_init)

# %%
# Rescale the data
#pos *= np.sqrt((X_true ** 2).sum()) / np.sqrt((pos ** 2).sum())
#npos *= np.sqrt((X_true ** 2).sum()) / np.sqrt((npos ** 2).sum())

# Rotate the data
clf = PCA()
X_true = clf.fit_transform(data2.iloc[:, 2:])

pos = clf.fit_transform(pos)

npos = clf.fit_transform(npos)

fig = plt.figure(1)
ax = plt.axes([0., 0., 1., 1.])

s = 10
Cil = np.repeat(3, data_Cil.shape[0])
Dil = np.repeat(1, data_Dil.shape[0])

Str = np.repeat(2, data_Stri.shape[0])
Obt = np.repeat(0, data_Obt.shape[0])
Hur = np.repeat(4, data_Hur.shape[0])

Species = np.concatenate((Obt, Dil, Str, Cil, Hur))

#plt.scatter(X_true[:, 0], X_true[:, 1], color='navy', s=s, lw=0,
            #label='True Position')
#plt.scatter(pos[:, 0], pos[:, 1], color='turquoise', s=s, lw=0, label='MDS')
#plt.scatter(npos[:, 0], npos[:, 1], color='darkorange', s=s, lw=0, label='NMDS')
#plt.legend(scatterpoints=1, loc='best', shadow=False)
col = ['blue',  'orange','green', 'gray', 'purple']
#i=0
#for types in set(Species):
   # plt.scatter(npos[Species==types, 0],
  #          npos[Species==types, 1],s=s, lw= 0, c=col[i])
 #   i+=1
#
#plt.legend(set(Species), loc='best', shadow='TRUE')


i=0
for types in set(Species):
    plt.plot(npos[Species==types, 0],
            npos[Species==types, 1], 'o', c=col[i])
    #plt.xlim(-0.13, -0.11)
    #plt.ylim(-0.02,0)
    i+=1

#plt.legend(set(Species), loc='best', shadow='TRUE')
#npos
# Out:
# /Users/ryokubo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:43: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 120 but corresponding boolean dimension is 89
# /Users/ryokubo/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:44: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 120 but corresponding boolean dimension is 89
