# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataAll = pd.read_csv('Platanthera_all.csv', header = 0)
dataObt = pd.read_excel('Orchids_processed_70percent.xlsx.xlsx', sheetname ='Obtusata' )
dataDil = pd.read_excel('Orchids_processed_70percent.xlsx.xlsx', sheetname ='Dilatata' )
dataStricta = pd.read_excel('Orchids_processed_70percent.xlsx.xlsx', sheetname ='Stricta et S' )
dataPink = pd.read_excel('Orchids_processed_70percent.xlsx.xlsx', sheetname = 'Pink')

# %%
data_ObtT = dataObt.T
data_DilT = dataDil.T
data_StricT = dataStricta.T
data_Pink = dataPink.T

# %%
data_ObtMean = data_ObtT.dropna()
data_ObtMean
#data_ObtMean = data_ObtMean[data_ObtMean.iloc[:, 1].str.contains('Pobtusata')]
#data_DilMean = data_DilMean[data_DilMean.iloc[:, 1].str.contains('dilatata')]
#data_StrMean = data_StrMean[data_Mean.iloc[:, 1].str.contains('')]
# Out:
#                                                                    0    \
# Chemical_Name                                       Undecane, 3-ethyl-
# 150818_D6_concentrated_processed                                     0
# 150706_D12_Pobtusata_48hrs_2plantes_14F_040715_...                   0
# 150706_A3_Pobtusata_2plantes_11F_190615_processed                    0
# 150706_D11_Pobtusata_48hrs_2plantes_17F_040715_...                   0
# 150706_C3_Pobtusata_24hrs_3plantes_26F_190615_p...                   0
# 150707_C5_Pobtusata_48hrs_6plants_50F_240615_pr...                   0
# 150818_D11_concentrated_processed                                    0
# 150706_D8_Pobtusata_48hrs_1plante_12F_260615_pr...                   0
# 150623_OBTUSATA_A2_150618_processed                                  0
# 150818_C4_concentrated_processed                                     0
# 150706_D9_Pobtusata_48hrs_3plantes_12F_260615_p...                   0
# ...

# %%
ObtRows = data_ObtT.index[1:]
DilRows = data_DilT.index[1:]
StrictRows = data_StricT.index[1:]
PinkRows = data_Pink.index[1:]

# Extracting the sample names and controls separately to use for 
# P obtusata
# http://stackoverflow.com/qu oestions/4211209/remove-all-the-elements-that-occur-in-one-list-from-another
ObtSamples = ObtRows[ObtRows.str.contains('Pobtusata|OBTUSATA|P_obtusata|C4|D3|D4|D5|D6|D8|D11')]
ObtCtrls = [x for x in ObtRows if x not in ObtSamples]


# P dilatata
DilSamples =DilRows[DilRows.str.contains('dilatata')]
DilCtrls = [x for x in DilRows if x not in DilSamples]

# P stricta
StrictCtrls= StrictRows[StrictRows.str.contains('Empty|bag')]
StrictSamples = [x for x in StrictRows if x not in StrictCtrls]

# Pink Platanthera(?)
PinkCtrls = PinkRows[PinkRows.str.contains('Empty|bag')]
PinkSamples = [x for x in PinkRows if x not in PinkCtrls]

ObtSamples
# Out:
# Index(['150818_D6_concentrated_processed', '150818_D6_concentrated_normalized',
#        '150706_D12_Pobtusata_48hrs_2plantes_14F_040715_processed',
#        '150706_A3_Pobtusata_2plantes_11F_190615_processed',
#        '150706_D11_Pobtusata_48hrs_2plantes_17F_040715_processed',
#        '150706_C3_Pobtusata_24hrs_3plantes_26F_190615_processed',
#        '150707_C5_Pobtusata_48hrs_6plants_50F_240615_processed',
#        '150818_D11_concentrated_processed',
#        '150706_D8_Pobtusata_48hrs_1plante_12F_260615_processed',
#        '150623_OBTUSATA_A2_150618_processed',
#        '150818_C4_concentrated_processed',
#        '150706_D9_Pobtusata_48hrs_3plantes_12F_260615_processed',
#        '150707_D3_Pobtusata_24hrs_2plants_15F_190615_processed',
#        '150707_C1_Pobtusata_24hrs_1plante_15F_180615_processed',
#        '150707_D1_Pobtusata_24hrs_1plant_2F_180615_processed',
#        '150706_D14_Pobtusata_48hrs_2plantes_11F_040715_processed',
# ...

# %%
# the data is empty??? sflksh'fa wtf
data_ObtMean = data_ObtT[data_ObtT.iloc[:,:].str.contains('Pobtusata|OBTUSATA|P_obtusata|C4|D3|D4|D5|D6|D8|D11', na = False)]
data_DilMean = data_DilT[data_DilT.iloc[:,:].str.contains('dilatata', na = False)]
data_StrMean = data_StricT[data_StricT.iloc[:,:].str.contains('stricta', na = False)]

data_ObtT
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-94fc7848c027> in <module>()
#       1 # the data is empty??? sflksh'fa wtf
# ----> 2 data_ObtMean = data_ObtT[data_ObtT.iloc[:,:].str.contains('Pobtusata|OBTUSATA|P_obtusata|C4|D3|D4|D5|D6|D8|D11', na = False)]
#       3 data_DilMean = data_DilT[data_DilT.iloc[:,:].str.contains('dilatata', na = False)]
#       4 data_StrMean = data_StricT[data_StricT.iloc[:,:].str.contains('stricta', na = False)]
#       5
#
# /Users/ryokubo/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
Values = data_T.values
Values.shape

# %%
fig = 
for i in range(10)
plt.plot(Values[3,2:])
